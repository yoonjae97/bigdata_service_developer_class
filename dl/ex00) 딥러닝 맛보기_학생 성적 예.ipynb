# %% [markdown]
# 목표
# - 학생들의 수학 성적을 예측하는 회귀 모델을 만들어보자!
# - keras를 이용해 신경망을 구성하는 방법을 익혀보자!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/SW캠프 데이터비즈니스 과정'

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터비즈니스 과정
# Out:
# /content/drive/MyDrive/Colab Notebooks/SW캠프 데이터비즈니스 과정

# %%
data = pd.read_csv('data/student-mat.csv', delimiter=";")
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# 0         no     yes    yes       no       no       4         3      4     1
# 1         no      no    yes      yes       no       5         3      3     1
# 2         no     yes    yes      yes       no       4         3      2     2
# 3        yes     yes    yes      yes      yes       3         2      2     1
# 4         no     yes    yes       no       no       4         3      2     1
#
#    Walc  health  absences  G1  G2  G3
# 0     1       3         6   5   6   6
# 1     1       3         4   5   5   6
# 2     3       3        10   7   8  10
# 3     1       5         2  15  14  15
# 4     2       5         4   6  10  10

# %%
# 모든 컬럼 표시
pd.set_option("display.max_columns", None)

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         3       yes     no  yes
# 3      home   mother           1          3         0        no    yes  yes
# 4      home   father           1          2         0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course    other           1          2         2        no    yes  yes
# 391  course   mother           2          1         0        no     no   no
# 392  course    other           1          1         3        no     no   no
# 393  course   mother           3          1         0        no     no   no
# 394  course   father           1          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 390         no     yes    yes       no       no       5         5      4
# 391         no      no    yes      yes       no       2         4      5
# 392         no      no    yes       no       no       5         5      3
# 393         no      no    yes      yes       no       4         4      1
# 394         no     yes    yes      yes       no       3         2      3
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         6   5   6   6
# 1       1     1       3         4   5   5   6
# 2       2     3       3        10   7   8  10
# 3       1     1       5         2  15  14  15
# 4       1     2       5         4   6  10  10
# ..    ...   ...     ...       ...  ..  ..  ..
# 390     4     5       4        11   9   9   9
# 391     3     4       2         3  14  16  16
# 392     3     3       3         3  10   8   7
# 393     3     4       5         0  11  12  10
# 394     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# - 문제, 정답 분리

# %%
# 문제는 studytime, 정답은 G3
X = data['studytime']
y = data['G3']

# %%
X.shape, y.shape
# Out:
# ((395,), (395,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (296,)
# (99,)
# (296,)
# (99,)

# %% [markdown]
# ### 신경망 모델만들기
# - 1. 신경망 구조 설계
# - 2. 신경망 학습 및 평가 방법 설정
# - 3. 학습 및 학습과정 시각화
# - 4. 모델평가

# %%
# 1. 신경망 구조설계
# Sequential : 신경망의 뼈대를 구축하기 위한 함수
from tensorflow.keras import Sequential
# InputLayer : 신경망의 입력층을 생성
# Dense : 신경망 층(뉴런의 묶음)을 구성해주는 함수
from tensorflow.keras.layers import InputLayer, Dense

# %%
# 1. 신경망 구조설계
model = Sequential()

# 입력층 설정
# input_shape : 입력 데이터의 특성 형태를 설정(1개의 특성을 가진 1차원 데이터)
model.add(InputLayer(input_shape=(1,)))

# 출력층 설정
# Dense : 하나의 층을 쌓아주는 함수(괄호 안의 숫자는 해당 층에 있는 뉴런의 개수)
model.add(Dense(1))

# 설계된 신경망의 정보를 요약해서 출력
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. 신경망 학습 및 평가방법 설정
# 손실함수(비용함수). 최적화함수 설정
model.compile(loss='mse',
              optimizer='SGD'
              )

# %%
# 3. 학습 및 시각화
h = model.fit(X_train, y_train,
              epochs=100
              )
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 2ms/step - loss: 52.2317
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 30.0891
# Epoch 3/100
# 10/10 [==============================] - 0s 2ms/step - loss: 27.5729
# Epoch 4/100
# 10/10 [==============================] - 0s 2ms/step - loss: 26.8822
# Epoch 5/100
# 10/10 [==============================] - 0s 4ms/step - loss: 26.4659
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 26.0673
# Epoch 7/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.7479
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 25.3844
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 25.0318
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.7167
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.4010
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 24.0830
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.8548
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.4848
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.1788
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.9133
# Epoch 17/100
# 10/10 [==============================] - 0s 2ms/step - loss: 22.6987
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.4828
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.2409
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.0125
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.8400
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.7166
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.4846
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.3443
# Epoch 25/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.1802
# Epoch 26/100
# 10/10 [==============================] - 0s 2ms/step - loss: 21.0433
# Epoch 27/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.8896
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.7928
# Epoch 29/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.6084
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.5208
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.4596
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.3054
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.1729
# Epoch 34/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.1101
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.0181
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.9584
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.8162
# Epoch 38/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.7141
# Epoch 39/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.6423
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.5872
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5099
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.4674
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.4091
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3224
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.2564
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.2660
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.2054
# Epoch 48/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1372
# Epoch 49/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.0801
# Epoch 50/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.0481
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.9539
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.8973
# Epoch 53/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9765
# Epoch 54/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8394
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8311
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7738
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7543
# Epoch 58/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6905
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6901
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6537
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6572
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5838
# Epoch 63/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6458
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5910
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5444
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5945
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4418
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4699
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4707
# Epoch 70/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4875
# Epoch 71/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4511
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3899
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4111
# Epoch 74/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3434
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3390
# Epoch 76/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3638
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3393
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3195
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2859
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2947
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3564
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3308
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.2448
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.2564
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2553
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.2249
# Epoch 87/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2067
# Epoch 88/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2813
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2630
# Epoch 90/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2263
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2110
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2069
# Epoch 93/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1999
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.2204
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1913
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1910
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.1665
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.1516
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2587
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.1686

# %%
# 3. 학습과정 시각화
plt.figure(figsize=(15, 5))

# history : 학습시 출력되는 값(loss, acc)들을 가져올 수 있게 해주는 명령
plt.plot(h.history['loss'], label='loss')

plt.legend()
plt.show()

# %% [markdown]
# - 초반에는 빠르게 loss값(mse)이 떨어지고 있음
# - 경사하강법 초반에는 가중치(w), 절편(b)값이 임의의 값으로 설정되어 있기 때문에 몇 번만 학습시켜도 mse가 빠르게 줄어드는 것을 볼 수 있음

# %%
# 4. 모델평가
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 29.7203
# 29.72031593322754

# %% [markdown]
# ### 입력 특성이 2개인 모델을 직접 만들어보자
# - 문제(studytime, traveltime) - X1
# - 정답(G3) - y1

# %%
X = data[['studytime', 'traveltime']]
y = data['G3']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)

# %%
from pandas.core.groupby.base import maybe_normalize_deprecated_kernels
model = Sequential()
model.add(InputLayer(input_shape=(2,)))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse',
              optimizer='SGD'
              )

# %%
h = model.fit(X_train, y_train,
            epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 0s 3ms/step - loss: 82.0577
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 26.1127
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 24.1813
# Epoch 4/100
# 10/10 [==============================] - 0s 4ms/step - loss: 24.0292
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.9951
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 23.7046
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.5559
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.3720
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.1917
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 23.0917
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.9031
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.7471
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.8828
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.5447
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.4658
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.3951
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.1380
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.1509
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.8904
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 22.0068
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.7752
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.6180
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.4932
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.3810
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.2426
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.2732
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.1958
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 21.0471
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.9295
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.8693
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.7880
# Epoch 32/100
# 10/10 [==============================] - 0s 4ms/step - loss: 20.6411
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.5905
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.5578
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.5110
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.3869
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.2983
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.1755
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.2026
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 20.0647
# Epoch 41/100
# 10/10 [==============================] - 0s 2ms/step - loss: 20.0386
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.9463
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.9982
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.9311
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.8068
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.7684
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.6662
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.6335
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5742
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.5593
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.4788
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.4498
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.4501
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.3686
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3246
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3116
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.3296
# Epoch 58/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.2711
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1905
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1341
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1783
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.0490
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 19.0555
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9816
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 19.1118
# Epoch 66/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9342
# Epoch 67/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9343
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.9176
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8403
# Epoch 70/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.8382
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.7696
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7343
# Epoch 73/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7211
# Epoch 74/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7351
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6621
# Epoch 76/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6583
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6593
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.6296
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.7345
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5787
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.6083
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5152
# Epoch 83/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5311
# Epoch 84/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5112
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.5202
# Epoch 86/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4632
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.5457
# Epoch 88/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4420
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4215
# Epoch 90/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4632
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.4056
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4008
# Epoch 93/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4056
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.4360
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3441
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 18.3055
# Epoch 97/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2912
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.3243
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2742
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 18.2256

# %%
plt.figure(figsize=(15, 5))
plt.plot(h.history['loss'], label='loss')

plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 28.2325
# 28.232507705688477
